# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal7829/se-exam/blob/main/22cs054.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x=df.iloc[:,[3,4]].values

# %%
from sklearn.cluster import KMeans
wcss_list=[]

# %%
from sklearn.cluster import KMeans
wcss_list=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(x)
    wcss_list.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
wcss_list=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(x)
    wcss_list.append(kmeans.inertia_)

plt.plot(range(1,11),wcss_list)
plt.title('the elbow method graph')
plt.xlabel('number of clusters')
plt.ylabel('wcss_list')
plt.show()
